# %%
import os
import pandas as pd
import numpy as np

#Import json files
data1 = os.path.join(".", "purchase_data.json")
data2 = os.path.join(".", "purchase_data2.json")

#Read the imported json file
data1_pd = pd.read_json(data1)
data1_pd.head()

#Read the imported json file (when needed remove comments)
#data2_pd = pd.read_csv(data2)
#data2_pd.head()
# Out:
#    Age Gender  Item ID                                  Item Name  Price  \
# 0   38   Male      165                Bone Crushing Silver Skewer   3.37
# 1   21   Male      119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2   34   Male      174                            Primitive Blade   2.46
# 3   21   Male       92                               Final Critic   1.36
# 4   23   Male       63                             Stormfury Mace   1.27
#
#              SN
# 0     Aelalis34
# 1        Eolo46
# 2   Assastnya25
# 3  Pheusrical25
# 4        Aela59

# %%
#Total Number of Players
Total_Players = data1_pd['SN'].count()
Total_Players
# Out:
# 780

# %%
#Number of Unique Items
Unique_items = data1_pd['Item Name'].value_counts()
Unique_items
# Out:
# Final Critic                                    14
# Betrayal, Whisper of Grieving Widows            11
# Arcane Gem                                      11
# Stormcaller                                     10
# Trickster                                        9
# Woeful Adamantite Claymore                       9
# Retribution Axe                                  9
# Serenity                                         9
# Conqueror Adamantite Mace                        8
# Bonecarvin Battle Axe                            8
# Splitter, Foe Of Subtlety                        8
# Crucifer                                         8
# Darkheart                                        8
# Crying Steel Sickle                              8
# Torchlight, Bond of Storms                       7
# Persuasion                                       7
# Alpha                                            7
# Victor Iron Spikes                               7
# Feral Katana                                     7
# Blade of the Grave                               7
# Wolf, Promise of the Moonwalker                  7
# Spectral Diamond Doomblade                       7
# Brimstone                                        7
# Alpha, Oath of Zeal                              7
# Darkheart, Butcher of the Champion               7
# Extraction, Quickblade Of Trembling Hands        7
# Blazeguard, Reach of Eternity                    6
# Malificent Bag                                   6
# Celeste                                          6
# Singed Scalpel                                   6
#                                                 ..
# Foul Titanium Battle Axe                         2
# Deathraze                                        2
# Warped Fetish                                    2
# Piece Maker                                      2
# Winter's Bite                                    2
# Tranquility, Razor of Black Magic                2
# Worldbreaker                                     2
# Thorn, Conqueror of the Corrupted                2
# Warped Iron Scimitar                             2
# Vindictive Glass Edge                            2
# Yearning Crusher                                 2
# Freak's Bite, Favor of Holy Might                2
# Blazefury, Protector of Delusions                2
# Fusion Pummel                                    2
# Renewed Skeletal Katana                          2
# Oathbreaker, Last Hope of the Breaking Storm     2
# Bloodlord's Fetish                               1
# Downfall, Scalpel Of The Emperor                 1
# Phantomlight                                     1
# Foul Edge                                        1
# Soul-Forged Steel Shortsword                     1
# Hellreaver, Heirloom of Inception                1
# Splinter                                         1
# Verdict                                          1
# Flux, Destroyer of Due Diligence                 1
# Exiled Doomblade                                 1
# Ghastly Adamantite Protector                     1
# Sun Strike, Jaws of Twisted Visions              1
# Exiled Mithril Longsword                         1
# Lightning, Etcher of the King                    1
# Name: Item Name, Length: 179, dtype: int64

# %%
#Average Purchase Price
Avg_Price = data1_pd['Price'].mean()
Avg_Price
# Out:
# 2.931192307692303

# %%
#Total Number of Purchases
Total_Purch = data1_pd['Item Name'].count()
Total_Purch
# Out:
# 780

# %%
# Total Revenue
Total_Rev = data1_pd['Price'].sum()
Total_Rev
# Out:
# 2286.3299999999963

# %%
#Gender Demo - Gender Counts
Gender_Count = data1_pd['Gender'].value_counts()
Gender_Count
# Out:
# Male                     633
# Female                   136
# Other / Non-Disclosed     11
# Name: Gender, dtype: int64

# %%
#Gender Demo - Gender Percentage
Gender_Percent = Gender_Count / data1_pd['Gender'].count()
Gender_Percent
# Out:
# Male                     0.811538
# Female                   0.174359
# Other / Non-Disclosed    0.014103
# Name: Gender, dtype: float64

# %%
#Purchase Analysis - Male Data
Male_data = data1_pd.loc[data1_pd["Gender"].astype(str) == 'Male',:]
Male_data
# Out:
#      Age Gender  Item ID                                  Item Name  Price  \
# 0     38   Male      165                Bone Crushing Silver Skewer   3.37
# 1     21   Male      119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2     34   Male      174                            Primitive Blade   2.46
# 3     21   Male       92                               Final Critic   1.36
# 4     23   Male       63                             Stormfury Mace   1.27
# 5     20   Male       10                                Sleepwalker   1.73
# 6     20   Male      153                            Mercenary Sabre   4.57
# 8     25   Male      118           Ghost Reaver, Longsword of Magic   2.77
# 9     31   Male       99       Expiration, Warscythe Of Lost Worlds   4.53
# 10    24   Male       57            Despair, Favor of Due Diligence   3.81
# 11    20   Male       47                Alpha, Reach of Ending Hope   1.55
# 12    30   Male       81                                  Dreamkiss   4.06
# 13    23   Male       77                 Piety, Guardian of Riddles   3.68
# 14    40   Male       44                      Bonecarvin Battle Axe   2.46
# 15    21   Male       96                Blood-Forged Skeletal Spine   4.77
# 18    28   Male       91                                    Celeste   3.71
# 19    31   Male      177   Winterthorn, Defender of Shifting Worlds   4.89
# 20    24   Male       78                 Glimmer, Ender of the Moon   2.33
# 21    15   Male        3                               Phantomlight   1.79
# 23    19   Male      183                        Dragon's Greatsword   2.36
# 24    11   Male       65                  Conqueror Adamantite Mace   1.96
# 25    21   Male       63                             Stormfury Mace   1.27
# 26    29   Male      132                                 Persuasion   3.90
# 27    34   Male      106                        Crying Steel Sickle   2.29
# 28    15   Male       49           The Oculus, Token of Lost Worlds   4.23
# 31    18   Male       37        Shadow Strike, Glory of Ending Hope   1.93
# 32    19   Male       48            Rage, Legacy of the Lone Victor   4.32
# 33    24   Male       90                                   Betrayer   1.67
# 34    22   Male       47                Alpha, Reach of Ending Hope   1.55
# 36    20   Male       44                      Bonecarvin Battle Axe   2.46
# ..   ...    ...      ...                                        ...    ...
# 744   21   Male      130                                      Alpha   1.56
# 745   20   Male       79                        Alpha, Oath of Zeal   2.88
# 746   35   Male       34                            Retribution Axe   4.14
# 747   32   Male       52                                     Hatred   4.39
# 748   15   Male      120                                     Agatha   1.91
# 749   21   Male      114                         Yearning Mageblade   1.79
# 750   23   Male       86                          Stormfury Lantern   1.28
# 753   20   Male        4                         Bloodlord's Fetish   2.28
# 754   31   Male      104                         Gladiator's Glaive   1.36
# 756   22   Male        6                                Rusty Skull   1.20
# 757   35   Male       11                                  Brimstone   2.52
# 758   20   Male      122                           Unending Tyranny   1.21
# 759   19   Male       87                   Deluge, Edge of the West   2.20
# 760   29   Male       81                                  Dreamkiss   4.06
# 761   28   Male      175                 Woeful Adamantite Claymore   1.24
# 762   36   Male       52                                     Hatred   4.39
# 764   25   Male       70                                 Hope's End   3.89
# 765   15   Male       13                                   Serenity   1.49
# 767   20   Male      122                           Unending Tyranny   1.21
# 768   21   Male      158         Darkheart, Butcher of the Champion   3.56
# 769   24   Male       73                                Ritual Mace   3.74
# 770   22   Male      141                                 Persuasion   3.27
# 771   24   Male       25                                  Hero Cane   1.03
# 772   15   Male       31                                  Trickster   2.07
# 773   21   Male       44                      Bonecarvin Battle Axe   2.46
# 774   24   Male      123                          Twilight's Carver   1.14
# 775   22   Male       98                Deadline, Voice Of Subtlety   3.62
# 776   14   Male      104                         Gladiator's Glaive   1.36
# 777   20   Male      117          Heartstriker, Legacy of the Light   4.15
# 778   20   Male       75                    Brutality Ivory Warmace   1.72
#
#                   SN
# 0          Aelalis34
# 1             Eolo46
# 2        Assastnya25
# 3       Pheusrical25
# 4             Aela59
# 5         Tanimnya91
# 6        Undjaskla97
# 8       Sondenasta63
# 9         Hilaerin92
# 10        Chamosia29
# 11           Sally64
# 12         Iskossa88
# 13   Seorithstilis90
# 14         Sundast29
# 15        Haellysu29
# 18         Iskista88
# 19         Assossa43
# 20           Irith83
# 21       Iaralrgue74
# 23        Chanosia65
# 24          Qarwen67
# 25            Idai61
# 26     Aerithllora36
# 27       Assastnya25
# 28       Ilariarin45
# 31         Iarilis73
# 32         Malunil62
# 33        Iskimnya76
# 34        Yararmol43
# 36          Undare39
# ..               ...
# 744     Ialistidru50
# 745      Sweecossa42
# 746        Ralasti48
# 747          Lamon28
# 748           Isri49
# 749    Frichassala85
# 750         Eollym91
# 753      Thryallym62
# 754      Sondastan54
# 756         Siasri67
# 757         Seosri62
# 758      Ryastycal90
# 759    Chanirrasta87
# 760    Aerithllora36
# 761      Raeduerin33
# 762      Lisosiast26
# 764     Assassasda84
# 765    Aerithnucal56
# 767      Hailaphos89
# 768     Chamucosda93
# 769   Frichilsasya78
# 770         Aenasu69
# 771       Lassista97
# 772          Sidap51
# 773    Chamadarsda63
# 774     Lassassast73
# 775          Eural50
# 776       Lirtossa78
# 777       Tillyrin30
# 778       Quelaton80
#
# [633 rows x 6 columns]

# %%
#Purchase Analysis - Male Purchase Count
Male_data["Item Name"].count()
# Out:
# 633

# %%
#Purchase Analysis - Male Average Purchase Price
Male_data["Price"].mean()
# Out:
# 2.9505213270142154

# %%
#Purchase Analysis - Male Total Purchase Value
Male_data["Price"].sum()
# Out:
# 1867.6799999999985

# %%
#Purchase Analysis - Male Noralized Totals
Male_data["Price"].std()
# Out:
# 1.10996659201214

# %%
#Purchase Analysis - Female Data
Female_data = data1_pd.loc[data1_pd["Gender"].astype(str) == 'Female',:]
Female_data
# Out:
#      Age  Gender  Item ID                                  Item Name  Price  \
# 7     29  Female      169     Interrogator, Blood Blade of the Queen   3.32
# 16    22  Female      123                          Twilight's Carver   1.14
# 17    22  Female       59              Lightning, Etcher of the King   1.65
# 22    11  Female       11                                  Brimstone   2.52
# 29    16  Female       45                        Glinting Glass Edge   2.46
# 30    21  Female      155                  War-Forged Gold Deflector   3.73
# 35    21  Female       13                                   Serenity   1.49
# 41    19  Female      124                             Venom Claymore   2.72
# 50    32  Female       32                                    Orenmir   4.95
# 54    25  Female      101                               Final Critic   4.62
# 58    24  Female       65                  Conqueror Adamantite Mace   1.96
# 62    19  Female       39       Betrayal, Whisper of Grieving Widows   2.35
# 70     7  Female      158         Darkheart, Butcher of the Champion   3.56
# 80    16  Female      128              Blazeguard, Reach of Eternity   4.00
# 83    25  Female       32                                    Orenmir   4.95
# 85    20  Female      150                                  Deathraze   4.54
# 96    22  Female       54                            Eternal Cleaver   3.14
# 97    17  Female       49           The Oculus, Token of Lost Worlds   4.23
# 106   37  Female      174                            Primitive Blade   2.46
# 109   20  Female       42                            The Decapitator   4.82
# 110   20  Female       13                                   Serenity   1.49
# 122   18  Female       53                          Vengeance Cleaver   3.70
# 125    7  Female       10                                Sleepwalker   1.73
# 127   23  Female       74                           Yearning Crusher   1.06
# 129   23  Female      126                   Exiled Mithril Longsword   3.25
# 133   17  Female      108  Extraction, Quickblade Of Trembling Hands   3.39
# 137   13  Female       20                                 Netherbane   1.48
# 154   27  Female       39       Betrayal, Whisper of Grieving Widows   2.35
# 156   17  Female       27            Riddle, Tribute of Ended Dreams   3.96
# 158   25  Female       66                         Victor Iron Spikes   3.55
# ..   ...     ...      ...                                        ...    ...
# 616   20  Female       11                                  Brimstone   2.52
# 620   20  Female       80                                  Dreamsong   3.81
# 623   39  Female      161                                     Devine   1.45
# 624   37  Female       95                      Singed Onyx Warscythe   1.03
# 645   20  Female      103                             Singed Scalpel   4.87
# 651   30  Female       79                        Alpha, Oath of Zeal   2.88
# 652   21  Female        8                   Purgatory, Gem of Regret   3.91
# 656   10  Female       63                             Stormfury Mace   1.27
# 664   22  Female       33                                 Curved Axe   1.35
# 678   26  Female       65                  Conqueror Adamantite Mace   1.96
# 680   13  Female       18                 Torchlight, Bond of Storms   1.77
# 681   20  Female      100                                Blindscythe   3.66
# 684   29  Female      130                                      Alpha   1.56
# 685    7  Female       11                                  Brimstone   2.52
# 687   15  Female      112                               Worldbreaker   3.29
# 689   16  Female       33                                 Curved Axe   1.35
# 694   20  Female       91                                    Celeste   3.71
# 695   37  Female      117          Heartstriker, Legacy of the Light   4.15
# 710   27  Female       67      Celeste, Incarnation of the Corrupted   2.31
# 718   22  Female       79                        Alpha, Oath of Zeal   2.88
# 724   13  Female      117          Heartstriker, Legacy of the Light   4.15
# 730   10  Female      148         Warmonger, Gift of Suffering's End   3.96
# 731   20  Female      106                        Crying Steel Sickle   2.29
# 732   23  Female       37        Shadow Strike, Glory of Ending Hope   1.93
# 739   35  Female       93                   Apocalyptic Battlescythe   3.91
# 751   26  Female      179            Wolf, Promise of the Moonwalker   1.88
# 752   15  Female      116                    Renewed Skeletal Katana   2.37
# 755   22  Female      179            Wolf, Promise of the Moonwalker   1.88
# 766   22  Female       84                                 Arcane Gem   2.23
# 779   23  Female      107                  Splitter, Foe Of Subtlety   3.61
#
#                 SN
# 7     Iathenudil29
# 16      Sundista85
# 17       Aenarap34
# 22        Deural48
# 29       Phaedai25
# 30      Eulaeria40
# 35         Aisur51
# 41         Aeral43
# 50    Saistyphos30
# 54       Minduli80
# 58     Tyaeristi78
# 62          Aeri84
# 70      Eosurdru76
# 80    Chanosseya79
# 83   Frichaststa61
# 85      Ithergue48
# 96       Yasurra52
# 97    Assassasta79
# 106     Chadossa56
# 109      Lassast89
# 110     Philodil43
# 122        Iliel92
# 125   Heosurnuru52
# 127      Eyircil84
# 129       Eurinu48
# 133   Sundossast30
# 137       Ilosia37
# 154     Lassilsa41
# 156        Marim28
# 158     Eodailis27
# ..             ...
# 616    Reuthelis39
# 620     Jiskilsa35
# 623    Mindimnya67
# 624     Tridaira71
# 645   Anallorgue57
# 651    Seuthelis34
# 652     Styaduen40
# 656     Ilaststa70
# 664   Sundaststa26
# 678        Rithe77
# 680   Chanosiast43
# 681       Sundim98
# 684   Iathenudil29
# 685      Lisirra55
# 687    Crausirra42
# 689      Eulidru49
# 694        Ririp86
# 695     Chadossa56
# 710   Tyaelorgue39
# 718      Phially37
# 724   Chanosiast43
# 730   Hiadanurin36
# 731      Tyaelly53
# 732       Shidai42
# 739      Cosadar58
# 751   Lisjasksda68
# 752  Yalostiphos68
# 755    Ailaesuir66
# 766    Nitherian58
# 779         Alim85
#
# [136 rows x 6 columns]

# %%
#Purchase Analysis - Female Purchase Count
Female_data["Item Name"].count()
# Out:
# 136

# %%
#Purchase Analysis - Female Average Purchase Price
Female_data["Price"].mean()
# Out:
# 2.815514705882352

# %%
#Purchase Analysis - Female Total Purchase Value
Female_data["Price"].sum()
# Out:
# 382.90999999999985

# %%
#Purchase Analysis - Female Noralized Totals
Female_data["Price"].std()
# Out:
# 1.1510271225384623

# %%
#Age Demographics 
data1_pd["Age"].describe()
# Out:
# count    780.000000
# mean      22.729487
# std        6.930604
# min        7.000000
# 25%       19.000000
# 50%       22.000000
# 75%       25.000000
# max       45.000000
# Name: Age, dtype: float64

# %%
#Create DataFrame
data1_df = pd.DataFrame(data1_pd)

# Create the bins in which Data will be held
# Bins are (< 10, 10-14, 15-19, 20-24, 25-29, 30-34,35-39, >45)
bins = [0, 9, 14, 19, 24, 29, 34, 39, 100]

groups = ['< 10', '10-14', '15-19', '20-24', '25-29', '30-34','35-39', '>45']

# Place the Ages into bins
pd.cut(data1_df["Age"], bins, labels = groups)
# Out:
# 0      35-39
# 1      20-24
# 2      30-34
# 3      20-24
# 4      20-24
# 5      20-24
# 6      20-24
# 7      25-29
# 8      25-29
# 9      30-34
# 10     20-24
# 11     20-24
# 12     30-34
# 13     20-24
# 14       >45
# 15     20-24
# 16     20-24
# 17     20-24
# 18     25-29
# 19     30-34
# 20     20-24
# 21     15-19
# 22     10-14
# 23     15-19
# 24     10-14
# 25     20-24
# 26     25-29
# 27     30-34
# 28     15-19
# 29     15-19
#        ...
# 750    20-24
# 751    25-29
# 752    15-19
# 753    20-24
# 754    30-34
# 755    20-24
# 756    20-24
# 757    35-39
# 758    20-24
# 759    15-19
# 760    25-29
# 761    25-29
# 762    35-39
# 763    25-29
# 764    25-29
# 765    15-19
# 766    20-24
# 767    20-24
# 768    20-24
# 769    20-24
# 770    20-24
# 771    20-24
# 772    15-19
# 773    20-24
# 774    20-24
# 775    20-24
# 776    10-14
# 777    20-24
# 778    20-24
# 779    20-24
# Name: Age, Length: 780, dtype: category
# Categories (8, object): [< 10 < 10-14 < 15-19 < 20-24 < 25-29 < 30-34 < 35-39 < >45]

# %%
#Summary of Bins
data1_df["Summary"] = pd.cut(data1_df["Age"], bins, labels=groups)
data1_df
# Out:
#      Age                 Gender  Item ID  \
# 0     38                   Male      165
# 1     21                   Male      119
# 2     34                   Male      174
# 3     21                   Male       92
# 4     23                   Male       63
# 5     20                   Male       10
# 6     20                   Male      153
# 7     29                 Female      169
# 8     25                   Male      118
# 9     31                   Male       99
# 10    24                   Male       57
# 11    20                   Male       47
# 12    30                   Male       81
# 13    23                   Male       77
# 14    40                   Male       44
# 15    21                   Male       96
# 16    22                 Female      123
# 17    22                 Female       59
# 18    28                   Male       91
# 19    31                   Male      177
# 20    24                   Male       78
# 21    15                   Male        3
# 22    11                 Female       11
# 23    19                   Male      183
# 24    11                   Male       65
# 25    21                   Male       63
# 26    29                   Male      132
# 27    34                   Male      106
# 28    15                   Male       49
# 29    16                 Female       45
# ..   ...                    ...      ...
# 750   23                   Male       86
# 751   26                 Female      179
# 752   15                 Female      116
# 753   20                   Male        4
# 754   31                   Male      104
# 755   22                 Female      179
# 756   22                   Male        6
# 757   35                   Male       11
# 758   20                   Male      122
# 759   19                   Male       87
# 760   29                   Male       81
# 761   28                   Male      175
# 762   36                   Male       52
# 763   27  Other / Non-Disclosed       48
# 764   25                   Male       70
# 765   15                   Male       13
# 766   22                 Female       84
# 767   20                   Male      122
# 768   21                   Male      158
# 769   24                   Male       73
# 770   22                   Male      141
# 771   24                   Male       25
# 772   15                   Male       31
# 773   21                   Male       44
# 774   24                   Male      123
# 775   22                   Male       98
# 776   14                   Male      104
# 777   20                   Male      117
# 778   20                   Male       75
# 779   23                 Female      107
#
#                                      Item Name  Price               SN Summary
# 0                  Bone Crushing Silver Skewer   3.37        Aelalis34   35-39
# 1    Stormbringer, Dark Blade of Ending Misery   2.32           Eolo46   20-24
# 2                              Primitive Blade   2.46      Assastnya25   30-34
# 3                                 Final Critic   1.36     Pheusrical25   20-24
# 4                               Stormfury Mace   1.27           Aela59   20-24
# 5                                  Sleepwalker   1.73       Tanimnya91   20-24
# 6                              Mercenary Sabre   4.57      Undjaskla97   20-24
# 7       Interrogator, Blood Blade of the Queen   3.32     Iathenudil29   25-29
# 8             Ghost Reaver, Longsword of Magic   2.77     Sondenasta63   25-29
# 9         Expiration, Warscythe Of Lost Worlds   4.53       Hilaerin92   30-34
# 10             Despair, Favor of Due Diligence   3.81       Chamosia29   20-24
# 11                 Alpha, Reach of Ending Hope   1.55          Sally64   20-24
# 12                                   Dreamkiss   4.06        Iskossa88   30-34
# 13                  Piety, Guardian of Riddles   3.68  Seorithstilis90   20-24
# 14                       Bonecarvin Battle Axe   2.46        Sundast29     >45
# 15                 Blood-Forged Skeletal Spine   4.77       Haellysu29   20-24
# 16                           Twilight's Carver   1.14       Sundista85   20-24
# 17               Lightning, Etcher of the King   1.65        Aenarap34   20-24
# 18                                     Celeste   3.71        Iskista88   25-29
# 19    Winterthorn, Defender of Shifting Worlds   4.89        Assossa43   30-34
# 20                  Glimmer, Ender of the Moon   2.33          Irith83   20-24
# 21                                Phantomlight   1.79      Iaralrgue74   15-19
# 22                                   Brimstone   2.52         Deural48   10-14
# 23                         Dragon's Greatsword   2.36       Chanosia65   15-19
# 24                   Conqueror Adamantite Mace   1.96         Qarwen67   10-14
# 25                              Stormfury Mace   1.27           Idai61   20-24
# 26                                  Persuasion   3.90    Aerithllora36   25-29
# 27                         Crying Steel Sickle   2.29      Assastnya25   30-34
# 28            The Oculus, Token of Lost Worlds   4.23      Ilariarin45   15-19
# 29                         Glinting Glass Edge   2.46        Phaedai25   15-19
# ..                                         ...    ...              ...     ...
# 750                          Stormfury Lantern   1.28         Eollym91   20-24
# 751            Wolf, Promise of the Moonwalker   1.88     Lisjasksda68   25-29
# 752                    Renewed Skeletal Katana   2.37    Yalostiphos68   15-19
# 753                         Bloodlord's Fetish   2.28      Thryallym62   20-24
# 754                         Gladiator's Glaive   1.36      Sondastan54   30-34
# 755            Wolf, Promise of the Moonwalker   1.88      Ailaesuir66   20-24
# 756                                Rusty Skull   1.20         Siasri67   20-24
# 757                                  Brimstone   2.52         Seosri62   35-39
# 758                           Unending Tyranny   1.21      Ryastycal90   20-24
# 759                   Deluge, Edge of the West   2.20    Chanirrasta87   15-19
# 760                                  Dreamkiss   4.06    Aerithllora36   25-29
# 761                 Woeful Adamantite Claymore   1.24      Raeduerin33   25-29
# 762                                     Hatred   4.39      Lisosiast26   35-39
# 763            Rage, Legacy of the Lone Victor   4.32       Eurisuru25   25-29
# 764                                 Hope's End   3.89     Assassasda84   25-29
# 765                                   Serenity   1.49    Aerithnucal56   15-19
# 766                                 Arcane Gem   2.23      Nitherian58   20-24
# 767                           Unending Tyranny   1.21      Hailaphos89   20-24
# 768         Darkheart, Butcher of the Champion   3.56     Chamucosda93   20-24
# 769                                Ritual Mace   3.74   Frichilsasya78   20-24
# 770                                 Persuasion   3.27         Aenasu69   20-24
# 771                                  Hero Cane   1.03       Lassista97   20-24
# 772                                  Trickster   2.07          Sidap51   15-19
# 773                      Bonecarvin Battle Axe   2.46    Chamadarsda63   20-24
# 774                          Twilight's Carver   1.14     Lassassast73   20-24
# 775                Deadline, Voice Of Subtlety   3.62          Eural50   20-24
# 776                         Gladiator's Glaive   1.36       Lirtossa78   10-14
# 777          Heartstriker, Legacy of the Light   4.15       Tillyrin30   20-24
# 778                    Brutality Ivory Warmace   1.72       Quelaton80   20-24
# 779                  Splitter, Foe Of Subtlety   3.61           Alim85   20-24
#
# [780 rows x 7 columns]

# %%
# Creating a group based off of the bins
Age_groups = data1_df.groupby("Summary")
#Purchase Counts
Age_groups['Item Name'].count()
# Out:
# Summary
# < 10      28
# 10-14     35
# 15-19    133
# 20-24    336
# 25-29    125
# 30-34     64
# 35-39     42
# >45       17
# Name: Item Name, dtype: int64

# %%
#Average Purchase Price
Age_groups['Price'].mean()
# Out:
# Summary
# < 10     2.980714
# 10-14    2.770000
# 15-19    2.905414
# 20-24    2.913006
# 25-29    2.962640
# 30-34    3.082031
# 35-39    2.842857
# >45      3.161765
# Name: Price, dtype: float64

# %%
#Total Purchase Value
Age_groups['Price'].sum()
# Out:
# Summary
# < 10      83.46
# 10-14     96.95
# 15-19    386.42
# 20-24    978.77
# 25-29    370.33
# 30-34    197.25
# 35-39    119.40
# >45       53.75
# Name: Price, dtype: float64

# %%
#Normalized Totals
Age_groups.std()
# Out:
#               Age    Item ID     Price
# Summary
# < 10     0.838082  53.684989  1.128358
# 10-14    1.316987  61.037211  1.103702
# 15-19    1.519937  55.148891  1.121010
# 20-24    1.512880  50.467797  1.112619
# 25-29    1.529284  49.619152  1.140724
# 30-34    1.387211  57.242433  1.176063
# 35-39    1.401841  55.651526  1.082714
# >45      1.416811  47.094633  0.898159

# %%
#Top Sepnders
grouped_df = data1_pd.groupby(['SN'])

# The object returned is a "GroupBy" object and cannot be viewed normally...
print(grouped_df)
# Out:
# <pandas.core.groupby.DataFrameGroupBy object at 0x00000221A2B83F28>

# %%
# In order to be visualized, a data function must be used...
grouped_df.head()
# Out:
#      Age                 Gender  Item ID  \
# 0     38                   Male      165
# 1     21                   Male      119
# 2     34                   Male      174
# 3     21                   Male       92
# 4     23                   Male       63
# 5     20                   Male       10
# 6     20                   Male      153
# 7     29                 Female      169
# 8     25                   Male      118
# 9     31                   Male       99
# 10    24                   Male       57
# 11    20                   Male       47
# 12    30                   Male       81
# 13    23                   Male       77
# 14    40                   Male       44
# 15    21                   Male       96
# 16    22                 Female      123
# 17    22                 Female       59
# 18    28                   Male       91
# 19    31                   Male      177
# 20    24                   Male       78
# 21    15                   Male        3
# 22    11                 Female       11
# 23    19                   Male      183
# 24    11                   Male       65
# 25    21                   Male       63
# 26    29                   Male      132
# 27    34                   Male      106
# 28    15                   Male       49
# 29    16                 Female       45
# ..   ...                    ...      ...
# 750   23                   Male       86
# 751   26                 Female      179
# 752   15                 Female      116
# 753   20                   Male        4
# 754   31                   Male      104
# 755   22                 Female      179
# 756   22                   Male        6
# 757   35                   Male       11
# 758   20                   Male      122
# 759   19                   Male       87
# 760   29                   Male       81
# 761   28                   Male      175
# 762   36                   Male       52
# 763   27  Other / Non-Disclosed       48
# 764   25                   Male       70
# 765   15                   Male       13
# 766   22                 Female       84
# 767   20                   Male      122
# 768   21                   Male      158
# 769   24                   Male       73
# 770   22                   Male      141
# 771   24                   Male       25
# 772   15                   Male       31
# 773   21                   Male       44
# 774   24                   Male      123
# 775   22                   Male       98
# 776   14                   Male      104
# 777   20                   Male      117
# 778   20                   Male       75
# 779   23                 Female      107
#
#                                      Item Name  Price               SN Summary
# 0                  Bone Crushing Silver Skewer   3.37        Aelalis34   35-39
# 1    Stormbringer, Dark Blade of Ending Misery   2.32           Eolo46   20-24
# 2                              Primitive Blade   2.46      Assastnya25   30-34
# 3                                 Final Critic   1.36     Pheusrical25   20-24
# 4                               Stormfury Mace   1.27           Aela59   20-24
# 5                                  Sleepwalker   1.73       Tanimnya91   20-24
# 6                              Mercenary Sabre   4.57      Undjaskla97   20-24
# 7       Interrogator, Blood Blade of the Queen   3.32     Iathenudil29   25-29
# 8             Ghost Reaver, Longsword of Magic   2.77     Sondenasta63   25-29
# 9         Expiration, Warscythe Of Lost Worlds   4.53       Hilaerin92   30-34
# 10             Despair, Favor of Due Diligence   3.81       Chamosia29   20-24
# 11                 Alpha, Reach of Ending Hope   1.55          Sally64   20-24
# 12                                   Dreamkiss   4.06        Iskossa88   30-34
# 13                  Piety, Guardian of Riddles   3.68  Seorithstilis90   20-24
# 14                       Bonecarvin Battle Axe   2.46        Sundast29     >45
# 15                 Blood-Forged Skeletal Spine   4.77       Haellysu29   20-24
# 16                           Twilight's Carver   1.14       Sundista85   20-24
# 17               Lightning, Etcher of the King   1.65        Aenarap34   20-24
# 18                                     Celeste   3.71        Iskista88   25-29
# 19    Winterthorn, Defender of Shifting Worlds   4.89        Assossa43   30-34
# 20                  Glimmer, Ender of the Moon   2.33          Irith83   20-24
# 21                                Phantomlight   1.79      Iaralrgue74   15-19
# 22                                   Brimstone   2.52         Deural48   10-14
# 23                         Dragon's Greatsword   2.36       Chanosia65   15-19
# 24                   Conqueror Adamantite Mace   1.96         Qarwen67   10-14
# 25                              Stormfury Mace   1.27           Idai61   20-24
# 26                                  Persuasion   3.90    Aerithllora36   25-29
# 27                         Crying Steel Sickle   2.29      Assastnya25   30-34
# 28            The Oculus, Token of Lost Worlds   4.23      Ilariarin45   15-19
# 29                         Glinting Glass Edge   2.46        Phaedai25   15-19
# ..                                         ...    ...              ...     ...
# 750                          Stormfury Lantern   1.28         Eollym91   20-24
# 751            Wolf, Promise of the Moonwalker   1.88     Lisjasksda68   25-29
# 752                    Renewed Skeletal Katana   2.37    Yalostiphos68   15-19
# 753                         Bloodlord's Fetish   2.28      Thryallym62   20-24
# 754                         Gladiator's Glaive   1.36      Sondastan54   30-34
# 755            Wolf, Promise of the Moonwalker   1.88      Ailaesuir66   20-24
# 756                                Rusty Skull   1.20         Siasri67   20-24
# 757                                  Brimstone   2.52         Seosri62   35-39
# 758                           Unending Tyranny   1.21      Ryastycal90   20-24
# 759                   Deluge, Edge of the West   2.20    Chanirrasta87   15-19
# 760                                  Dreamkiss   4.06    Aerithllora36   25-29
# 761                 Woeful Adamantite Claymore   1.24      Raeduerin33   25-29
# 762                                     Hatred   4.39      Lisosiast26   35-39
# 763            Rage, Legacy of the Lone Victor   4.32       Eurisuru25   25-29
# 764                                 Hope's End   3.89     Assassasda84   25-29
# 765                                   Serenity   1.49    Aerithnucal56   15-19
# 766                                 Arcane Gem   2.23      Nitherian58   20-24
# 767                           Unending Tyranny   1.21      Hailaphos89   20-24
# 768         Darkheart, Butcher of the Champion   3.56     Chamucosda93   20-24
# 769                                Ritual Mace   3.74   Frichilsasya78   20-24
# 770                                 Persuasion   3.27         Aenasu69   20-24
# 771                                  Hero Cane   1.03       Lassista97   20-24
# 772                                  Trickster   2.07          Sidap51   15-19
# 773                      Bonecarvin Battle Axe   2.46    Chamadarsda63   20-24
# 774                          Twilight's Carver   1.14     Lassassast73   20-24
# 775                Deadline, Voice Of Subtlety   3.62          Eural50   20-24
# 776                         Gladiator's Glaive   1.36       Lirtossa78   10-14
# 777          Heartstriker, Legacy of the Light   4.15       Tillyrin30   20-24
# 778                    Brutality Ivory Warmace   1.72       Quelaton80   20-24
# 779                  Splitter, Foe Of Subtlety   3.61           Alim85   20-24
#
# [780 rows x 7 columns]

# %%
#Purchase Count
Purch_Count = grouped_df['Price'].count()

#Avgerage Purchase Price
Purch_Avg = grouped_df['Price'].mean()

#Sum up Total Purch
Purch_Total = grouped_df['Price'].sum()

# %%
#Create Table of Results
summary_table = pd.DataFrame({"Purchase Count":Purch_Count,
                                   "Average Purchase Price":Purch_Avg, 'Total Purchase Value' : Purch_Total})
#Final Summary_table
Final_Spender_df = summary_table.sort_values('Total Purchase Value', ascending=False)
Final_Spender_df.head(5)
# Out:
#              Average Purchase Price  Purchase Count  Total Purchase Value
# SN
# Undirrala66                3.412000               5                 17.06
# Saedue76                   3.390000               4                 13.56
# Mindimnya67                3.185000               4                 12.74
# Haellysu29                 4.243333               3                 12.73
# Eoda93                     3.860000               3                 11.58

# %%
#Most Popular Items
grouped_df = data1_pd.groupby(['Item Name'])

# The object returned is a "GroupBy" object and cannot be viewed normally...
print(grouped_df)
# Out:
# <pandas.core.groupby.DataFrameGroupBy object at 0x00000221A2B15C88>

# %%
# In order to be visualized, a data function must be used...
grouped_df.head()
# Out:
#      Age                 Gender  Item ID  \
# 0     38                   Male      165
# 1     21                   Male      119
# 2     34                   Male      174
# 3     21                   Male       92
# 4     23                   Male       63
# 5     20                   Male       10
# 6     20                   Male      153
# 7     29                 Female      169
# 8     25                   Male      118
# 9     31                   Male       99
# 10    24                   Male       57
# 11    20                   Male       47
# 12    30                   Male       81
# 13    23                   Male       77
# 14    40                   Male       44
# 15    21                   Male       96
# 16    22                 Female      123
# 17    22                 Female       59
# 18    28                   Male       91
# 19    31                   Male      177
# 20    24                   Male       78
# 21    15                   Male        3
# 22    11                 Female       11
# 23    19                   Male      183
# 24    11                   Male       65
# 25    21                   Male       63
# 26    29                   Male      132
# 27    34                   Male      106
# 28    15                   Male       49
# 29    16                 Female       45
# ..   ...                    ...      ...
# 727   25                   Male      139
# 728   22                   Male       48
# 729   16                   Male      134
# 732   23                 Female       37
# 735   10                   Male       16
# 736   19                   Male       45
# 738   25                   Male       56
# 739   35                 Female       93
# 743   20                   Male      134
# 747   32                   Male       52
# 748   15                   Male      120
# 749   21                   Male      114
# 750   23                   Male       86
# 752   15                 Female      116
# 753   20                   Male        4
# 754   31                   Male      104
# 756   22                   Male        6
# 758   20                   Male      122
# 759   19                   Male       87
# 760   29                   Male       81
# 762   36                   Male       52
# 763   27  Other / Non-Disclosed       48
# 764   25                   Male       70
# 767   20                   Male      122
# 771   24                   Male       25
# 774   24                   Male      123
# 775   22                   Male       98
# 776   14                   Male      104
# 777   20                   Male      117
# 778   20                   Male       75
#
#                                      Item Name  Price               SN Summary
# 0                  Bone Crushing Silver Skewer   3.37        Aelalis34   35-39
# 1    Stormbringer, Dark Blade of Ending Misery   2.32           Eolo46   20-24
# 2                              Primitive Blade   2.46      Assastnya25   30-34
# 3                                 Final Critic   1.36     Pheusrical25   20-24
# 4                               Stormfury Mace   1.27           Aela59   20-24
# 5                                  Sleepwalker   1.73       Tanimnya91   20-24
# 6                              Mercenary Sabre   4.57      Undjaskla97   20-24
# 7       Interrogator, Blood Blade of the Queen   3.32     Iathenudil29   25-29
# 8             Ghost Reaver, Longsword of Magic   2.77     Sondenasta63   25-29
# 9         Expiration, Warscythe Of Lost Worlds   4.53       Hilaerin92   30-34
# 10             Despair, Favor of Due Diligence   3.81       Chamosia29   20-24
# 11                 Alpha, Reach of Ending Hope   1.55          Sally64   20-24
# 12                                   Dreamkiss   4.06        Iskossa88   30-34
# 13                  Piety, Guardian of Riddles   3.68  Seorithstilis90   20-24
# 14                       Bonecarvin Battle Axe   2.46        Sundast29     >45
# 15                 Blood-Forged Skeletal Spine   4.77       Haellysu29   20-24
# 16                           Twilight's Carver   1.14       Sundista85   20-24
# 17               Lightning, Etcher of the King   1.65        Aenarap34   20-24
# 18                                     Celeste   3.71        Iskista88   25-29
# 19    Winterthorn, Defender of Shifting Worlds   4.89        Assossa43   30-34
# 20                  Glimmer, Ender of the Moon   2.33          Irith83   20-24
# 21                                Phantomlight   1.79      Iaralrgue74   15-19
# 22                                   Brimstone   2.52         Deural48   10-14
# 23                         Dragon's Greatsword   2.36       Chanosia65   15-19
# 24                   Conqueror Adamantite Mace   1.96         Qarwen67   10-14
# 25                              Stormfury Mace   1.27           Idai61   20-24
# 26                                  Persuasion   3.90    Aerithllora36   25-29
# 27                         Crying Steel Sickle   2.29      Assastnya25   30-34
# 28            The Oculus, Token of Lost Worlds   4.23      Ilariarin45   15-19
# 29                         Glinting Glass Edge   2.46        Phaedai25   15-19
# ..                                         ...    ...              ...     ...
# 727                    Mercy, Katana of Dismay   4.37         Eurith26   25-29
# 728            Rage, Legacy of the Lone Victor   4.32    Tyananurgue44   20-24
# 729                            Undead Crusader   4.67     Iskichinya81   15-19
# 732        Shadow Strike, Glory of Ending Hope   1.93         Shidai42   20-24
# 735                            Restored Bauble   3.11     Ethrusuard41   10-14
# 736                        Glinting Glass Edge   2.46      Indirrian56   15-19
# 738                   Foul Titanium Battle Axe   4.33        Tyadaru49   25-29
# 739                   Apocalyptic Battlescythe   3.91        Cosadar58   35-39
# 743                            Undead Crusader   4.67        Haedasu65   20-24
# 747                                     Hatred   4.39          Lamon28   30-34
# 748                                     Agatha   1.91           Isri49   15-19
# 749                         Yearning Mageblade   1.79    Frichassala85   20-24
# 750                          Stormfury Lantern   1.28         Eollym91   20-24
# 752                    Renewed Skeletal Katana   2.37    Yalostiphos68   15-19
# 753                         Bloodlord's Fetish   2.28      Thryallym62   20-24
# 754                         Gladiator's Glaive   1.36      Sondastan54   30-34
# 756                                Rusty Skull   1.20         Siasri67   20-24
# 758                           Unending Tyranny   1.21      Ryastycal90   20-24
# 759                   Deluge, Edge of the West   2.20    Chanirrasta87   15-19
# 760                                  Dreamkiss   4.06    Aerithllora36   25-29
# 762                                     Hatred   4.39      Lisosiast26   35-39
# 763            Rage, Legacy of the Lone Victor   4.32       Eurisuru25   25-29
# 764                                 Hope's End   3.89     Assassasda84   25-29
# 767                           Unending Tyranny   1.21      Hailaphos89   20-24
# 771                                  Hero Cane   1.03       Lassista97   20-24
# 774                          Twilight's Carver   1.14     Lassassast73   20-24
# 775                Deadline, Voice Of Subtlety   3.62          Eural50   20-24
# 776                         Gladiator's Glaive   1.36       Lirtossa78   10-14
# 777          Heartstriker, Legacy of the Light   4.15       Tillyrin30   20-24
# 778                    Brutality Ivory Warmace   1.72       Quelaton80   20-24
#
# [679 rows x 7 columns]

# %%
#Purchase Count
Purch_Count = grouped_df['Item Name'].count()

#Item ID
Item_ID = grouped_df["Item ID"].sum()

#Item Price
Item_Price = grouped_df["Price"].sum()


#Sum up Total Purch
Purch_Total = Purch_Count * Item_Price

# %%
#Create Table of Results
summary_table = pd.DataFrame({'Item ID':Item_ID, "Purchase Count":Purch_Count, "Item Price":Item_Price,
                            'Total Purchase Value' : Purch_Total})
#Final Summary_table
Final_Spender_df = summary_table.sort_values('Purchase Count', ascending=False,)
Final_Spender_df.head(5)
# Out:
#                                       Item ID  Item Price  Purchase Count  \
# Item Name
# Final Critic                             1342       38.60              14
# Arcane Gem                                924       24.53              11
# Betrayal, Whisper of Grieving Widows      429       25.85              11
# Stormcaller                              1050       34.65              10
# Woeful Adamantite Claymore               1575       11.16               9
#
#                                       Total Purchase Value
# Item Name
# Final Critic                                        540.40
# Arcane Gem                                          269.83
# Betrayal, Whisper of Grieving Widows                284.35
# Stormcaller                                         346.50
# Woeful Adamantite Claymore                          100.44

# %%
#Most Profitable Items
#Most Popular Items
grouped_df = data1_pd.groupby(['Item Name'])

# The object returned is a "GroupBy" object and cannot be viewed normally...
print(grouped_df)
# Out:
# <pandas.core.groupby.DataFrameGroupBy object at 0x00000221A2BA3400>

# %%
# In order to be visualized, a data function must be used...
grouped_df.head()
# Out:
#      Age  Gender  Item ID                                  Item Name  Price  \
# 0     38    Male      165                Bone Crushing Silver Skewer   3.37
# 1     21    Male      119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2     34    Male      174                            Primitive Blade   2.46
# 3     21    Male       92                               Final Critic   1.36
# 4     23    Male       63                             Stormfury Mace   1.27
# 5     20    Male       10                                Sleepwalker   1.73
# 6     20    Male      153                            Mercenary Sabre   4.57
# 7     29  Female      169     Interrogator, Blood Blade of the Queen   3.32
# 8     25    Male      118           Ghost Reaver, Longsword of Magic   2.77
# 9     31    Male       99       Expiration, Warscythe Of Lost Worlds   4.53
# 10    24    Male       57            Despair, Favor of Due Diligence   3.81
# 11    20    Male       47                Alpha, Reach of Ending Hope   1.55
# 12    30    Male       81                                  Dreamkiss   4.06
# 13    23    Male       77                 Piety, Guardian of Riddles   3.68
# 14    40    Male       44                      Bonecarvin Battle Axe   2.46
# 15    21    Male       96                Blood-Forged Skeletal Spine   4.77
# 16    22  Female      123                          Twilight's Carver   1.14
# 17    22  Female       59              Lightning, Etcher of the King   1.65
# 18    28    Male       91                                    Celeste   3.71
# 19    31    Male      177   Winterthorn, Defender of Shifting Worlds   4.89
# 20    24    Male       78                 Glimmer, Ender of the Moon   2.33
# 21    15    Male        3                               Phantomlight   1.79
# 22    11  Female       11                                  Brimstone   2.52
# 23    19    Male      183                        Dragon's Greatsword   2.36
# 24    11    Male       65                  Conqueror Adamantite Mace   1.96
# 25    21    Male       63                             Stormfury Mace   1.27
# 26    29    Male      132                                 Persuasion   3.90
# 27    34    Male      106                        Crying Steel Sickle   2.29
# 28    15    Male       49           The Oculus, Token of Lost Worlds   4.23
# 29    16  Female       45                        Glinting Glass Edge   2.46
# ..   ...     ...      ...                                        ...    ...
# 708   25    Male       73                                Ritual Mace   3.74
# 710   27  Female       67      Celeste, Incarnation of the Corrupted   2.31
# 712   13    Male        5                                 Putrid Fan   1.32
# 713   21    Male      159          Oathbreaker, Spellblade of Trials   3.01
# 714   24    Male       37        Shadow Strike, Glory of Ending Hope   1.93
# 719   25    Male      169     Interrogator, Blood Blade of the Queen   3.32
# 720    7    Male       82                                    Nirvana   1.11
# 723   20    Male       69            Frenzy, Defender of the Harvest   1.06
# 725   15    Male       14                             Possessed Core   1.59
# 727   25    Male      139                    Mercy, Katana of Dismay   4.37
# 729   16    Male      134                            Undead Crusader   4.67
# 732   23  Female       37        Shadow Strike, Glory of Ending Hope   1.93
# 735   10    Male       16                            Restored Bauble   3.11
# 738   25    Male       56                   Foul Titanium Battle Axe   4.33
# 743   20    Male      134                            Undead Crusader   4.67
# 747   32    Male       52                                     Hatred   4.39
# 748   15    Male      120                                     Agatha   1.91
# 749   21    Male      114                         Yearning Mageblade   1.79
# 750   23    Male       86                          Stormfury Lantern   1.28
# 752   15  Female      116                    Renewed Skeletal Katana   2.37
# 753   20    Male        4                         Bloodlord's Fetish   2.28
# 756   22    Male        6                                Rusty Skull   1.20
# 758   20    Male      122                           Unending Tyranny   1.21
# 759   19    Male       87                   Deluge, Edge of the West   2.20
# 760   29    Male       81                                  Dreamkiss   4.06
# 762   36    Male       52                                     Hatred   4.39
# 764   25    Male       70                                 Hope's End   3.89
# 767   20    Male      122                           Unending Tyranny   1.21
# 774   24    Male      123                          Twilight's Carver   1.14
# 778   20    Male       75                    Brutality Ivory Warmace   1.72
#
#                   SN Summary
# 0          Aelalis34   35-39
# 1             Eolo46   20-24
# 2        Assastnya25   30-34
# 3       Pheusrical25   20-24
# 4             Aela59   20-24
# 5         Tanimnya91   20-24
# 6        Undjaskla97   20-24
# 7       Iathenudil29   25-29
# 8       Sondenasta63   25-29
# 9         Hilaerin92   30-34
# 10        Chamosia29   20-24
# 11           Sally64   20-24
# 12         Iskossa88   30-34
# 13   Seorithstilis90   20-24
# 14         Sundast29     >45
# 15        Haellysu29   20-24
# 16        Sundista85   20-24
# 17         Aenarap34   20-24
# 18         Iskista88   25-29
# 19         Assossa43   30-34
# 20           Irith83   20-24
# 21       Iaralrgue74   15-19
# 22          Deural48   10-14
# 23        Chanosia65   15-19
# 24          Qarwen67   10-14
# 25            Idai61   20-24
# 26     Aerithllora36   25-29
# 27       Assastnya25   30-34
# 28       Ilariarin45   15-19
# 29         Phaedai25   15-19
# ..               ...     ...
# 708         Saedue76   25-29
# 710     Tyaelorgue39   25-29
# 712         Isketo41   10-14
# 713        Sundast87   20-24
# 714        Yadacal26   20-24
# 719        Iduedru67   25-29
# 720   Yarithsurgue62    < 10
# 723       Tillyrin30   20-24
# 725     Quarusrion32   15-19
# 727         Eurith26   25-29
# 729     Iskichinya81   15-19
# 732         Shidai42   20-24
# 735     Ethrusuard41   10-14
# 738        Tyadaru49   25-29
# 743        Haedasu65   20-24
# 747          Lamon28   30-34
# 748           Isri49   15-19
# 749    Frichassala85   20-24
# 750         Eollym91   20-24
# 752    Yalostiphos68   15-19
# 753      Thryallym62   20-24
# 756         Siasri67   20-24
# 758      Ryastycal90   20-24
# 759    Chanirrasta87   15-19
# 760    Aerithllora36   25-29
# 762      Lisosiast26   35-39
# 764     Assassasda84   25-29
# 767      Hailaphos89   20-24
# 774     Lassassast73   20-24
# 778       Quelaton80   20-24
#
# [622 rows x 7 columns]

# %%
#Item ID
Item_ID = grouped_df["Item ID"].sum()

#Item Price
Item_Price = grouped_df["Price"].max()

#Purchase Count
Purch_Count = grouped_df['Price'].count()


#Sum up Total Purch
Purch_Total = Purch_Count * Item_Price

# %%
#Create Table of Results
summary_table = pd.DataFrame({'Item ID':Item_ID, "Purchase Count":Purch_Count, "Item Price":Item_Price,
                            'Total Purchase Value' : Purch_Total})
#Final Summary_table
Final_Spender_df = summary_table.sort_values('Total Purchase Value', ascending=False,)
Final_Spender_df.head(5)
# Out:
#                                       Item ID  Item Price  Purchase Count  \
# Item Name
# Final Critic                             1342       38.60              14
# Stormcaller                              1050       34.65              10
# Retribution Axe                           306       37.26               9
# Betrayal, Whisper of Grieving Widows      429       25.85              11
# Arcane Gem                                924       24.53              11
#
#                                       Total Purchase Value
# Item Name
# Final Critic                                        540.40
# Stormcaller                                         346.50
# Retribution Axe                                     335.34
# Betrayal, Whisper of Grieving Widows                284.35
# Arcane Gem                                          269.83
